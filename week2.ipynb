# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import os
for dirname, _, filenames in os.walk('/kaggle/input/image-processing/brain.jpg'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

img1 = cv2.imread('/kaggle/input/image-processing/brain.jpg')
#Resmin boyutunu öğrenmek için:
print(img1.size)
#Resmin veri tipini öğrenmek için:
print (img1.dtype)
#Resmin genişliğini, yüksekliğini ve kaç kanaldan oluştuğunu öğrenmek için:
print (img1.shape)

plt.imshow(img1)
# Out:
# 537600
# uint8
# (320, 560, 3)
